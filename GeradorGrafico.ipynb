# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.metrics import classification_report, confusion_matrix
from keras.utils import np_utils
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import normalize
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

# %%
class GeradorGrafico():

    def __init__(self):
        
        self.valoresAcoesPetro=[]
        self.datasPetro=[]
        self.valoresAcoesVale=[]
        self.datasVale=[]
        self.valoresAcoesEmbraer=[]
        self.datasEmbraer=[]
    
    def LoadHistoricoAcoes(self):
        
        base = pd.read_csv('./PETR3.SA.csv')
        self.valoresAcoesPetro = base.iloc[:, [4]].values.tolist()
        self.datasPetro = base.iloc[:, [0]].values.tolist()
        
        base = pd.read_csv('./VALE3.SA.csv')
        self.valoresAcoesVale = base.iloc[:, [4]].values
        datasVale = base.iloc[:, [0]]
        
        base = pd.read_csv('./EMBR3.SA.csv')
        self.valoresAcoesEmbraer = base.iloc[:, [4]].values
        datasEmbraer = base.iloc[:, [0]]
        
        
        
    def ExibirGrafigo(self):
        
        
        plt.rcParams["figure.figsize"] = [27.50, 3.50]
        plt.rcParams["figure.autolayout"] = True
        
        fig = plt.figure()
        
        self.LoadHistoricoAcoes()
        
        #print(self.datasPetro)
        
        #input("Datas Petro")       
           
        indiceData=np.arange(len(self.valoresAcoesPetro))
        
        lstIndiceData = indiceData.tolist()        
    
        
        #print(lstIndiceData)

        #input("Indice das Datas em Lista ")
        
        #indiceDataT = indiceData.reshape(indiceData.shape[0],1)
 
        #print(indiceDataT)        
        #input("Indice Data TRansposta")
        

        
        plt.xlabel("Dia")  
        plt.ylabel("Valor Fechamento") 
        
        plt.plot(indiceData[:1263],self.valoresAcoesPetro[:1263],color='blue')
        
        plt.plot(indiceData[1264:],self.valoresAcoesPetro[1264:],color='red')
        
           
        plt.xticks(indiceData, self.datasPetro) 
        
         
        plt.xticks(np.arange(0, len(indiceData)+1, 100))
        
        spacing = 0.100
        fig.subplots_adjust(bottom=spacing)
        
        plt.show()

# %%
plotador = GeradorGrafico()
plotador.ExibirGrafigo()
